# %%
import tensorflow as tf
import tensorflow_hub as hub
import joblib
import gzip
import kipoiseq
from kipoiseq import Interval
import pyfaidx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import sys
from deeplift import dinuc_shuffle
import sonnet as snt
import tensorflow_addons as tfa
from tensorflow import strings as tfs
import modisco.visualization
from modisco.visualization import viz_sequence

# %%
base_scores = np.load("../data_and_analyses/Enformer_scores/CD69RE4_fine_tuned_FigS1D_3D/Jurkat_activated.basescores.npy",
                     allow_pickle=True)
fig = viz_sequence.plot_weights(base_scores[98140:98176,:], subticks_frequency=20)
fig.figure.savefig('jurkat_activated_logplot.pdf')
